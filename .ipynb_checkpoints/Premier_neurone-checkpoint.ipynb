# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# # 1. Dataset

# %%
X, y = make_blobs(n_samples=100, n_features=2, centers=2, random_state=0)

X[:, 1] = X[:, 1]*2

y = y.reshape((y.shape[0], 1))

print('dimensions de X:', X.shape)
print('dimensions de y:', y.shape)

plt.scatter(X[:,0], X[:, 1], c=y, cmap='summer')
plt.show()
# Out:
# dimensions de X: (100, 2)
# dimensions de y: (100, 1)

# %% [markdown]
# # 2. Fonctions du modele

# %%
def initialisation(X):
    W = np.random.randn(X.shape[1], 1)
    b = np.random.randn(1)
    return (W, b)

# %%
from math import exp, log

# %%
log(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 log(0)
#
# ValueError: math domain error

# %%
z = 1000
np.exp(-z)
1 / (1 + np.exp(-z))
# Out:
# 1.0

# %%
def model(X, W, b):
    Z = X.dot(W) + b
    A = 1 / (1 + np.exp(-Z))
    return A

# %%
def log_loss(A, y):
    epsilon = 1e-15
    return 1 / len(y) * np.sum(-y * np.log(A + epsilon) - (1 - y) * np.log(1 - A + epsilon))

# %%
def gradients(A, X, y):
    dW = 1 / len(y) * np.dot(X.T, A - y)
    db = 1 / len(y) * np.sum(A - y)
    return (dW, db)

# %%
def update(dW, db, W, b, learning_rate):
    W = W - learning_rate * dW
    b = b - learning_rate * db
    return (W, b)

# %%
def predict(X, W, b):
    A = model(X, W, b)
    # print(A)
    return A >= 0.5

# %%
from sklearn.metrics import accuracy_score

# %%
def artificial_neuron_2(X, y, learning_rate = 0.1, n_iter = 100):
    # initialisation W, b
    w, b = initialisation(X)
    w[0], w[1] = -7.5, -7.5

    nb = 10
    j=0
    history = np.zero((n_iter // nb, 5))

    Loss = []

    for i in range(n_iter):
        A = model(X, W, b)
        Loss.append(log_loss(A, y))
        dW, db = gradients(A, X, y)
        W, b = update(dW, db, W, b, learning_rate)
    if (i % nb == 0):
        history[j, 0] = w[0]
        history[j, 1] = w[1]
        history[j, 2] = b
        history[j, 3] = i
        history[j, 4] = log_loss(y, A)
        j +=1
    #y_pred = predict(X, W, b)
    #print(accuracy_score(y, y_pred))

    plt.plot(Loss)
    plt.show()

    return history, b
    #return (W, b)

# %%
history, b = artificial_neuron_2(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 history, b = artificial_neuron_2(X, y)
#
# Cell In[85], line 4, in artificial_neuron_2(X, y, learning_rate, n_iter)
#       1 def artificial_neuron_2(X, y, learning_rate = 0.1, n_iter = 100):
#       2     # initialisation W, b
#       3     W, b = initialisation(X)
# ----> 4     w[0], w[1] = -7.5, -7.5
#       6     nb = 10
#       7     j=0
#
# NameError: name 'w' is not defined

# %% [markdown]
# # 3. Frontiere de décision

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.scatter(X[:,0], X[:, 1], c=y, cmap='summer')

x1 = np.linspace(-1, 4, 100)
x2 = ( - W[0] * x1 - b) / W[1]

ax.plot(x1, x2, c='orange', lw=3)

# %% [markdown]
# # Exercice - Cat vs Dog

# %%
from utilities import *

# %%
X_train, y_train, X_test, y_test = load_data()

# %%
print(X_train.shape)
print(y_train.shape)
print(np.unique(y_train, return_counts= True))
# Out:
# (1000, 64, 64)
# (1000, 1)
# (array([0., 1.]), array([500, 500]))

# %%
print(X_test.shape)
print(y_test.shape)
print(np.unique(y_test, return_counts=True))
# Out:
# (200, 64, 64)
# (200, 1)
# (array([0., 1.]), array([100, 100]))

# %%
plt.figure(figsize=(16, 8))
for i in range(1, 10):
    plt.subplot(4,5,i)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(y_train[i])
    plt.tight_layout()
plt.show()

# %% [markdown]
# ## Entrainement du Modele

# %%
X_train_reshape = X_train.reshape(X_train.shape[0], -1)
X_train_reshape.shape
# Out:
# (1000, 4096)

# %%
X_test_reshape = X_test.reshape(X_test.shape[0], -1)
X_test_reshape.shape
# Out:
# (200, 4096)

# %%
W, b = artificial_neuron(X_train_reshape, y_train)
# Out:
# /tmp/ipykernel_3669/1615515945.py:3: RuntimeWarning: overflow encountered in exp
#   A = 1 / (1 + np.exp(-Z))
# 0.5

# %%
lim = 10
h = 100
w1 = np.linspace(-lim, lim,  h)
w2 = np.linspace(-lim, lim, h)

w11, w22 = np.meshgrid(w1, w2)

w_final = np.c_[w11.ravel(), w22.ravel()].T
w_final.shape
# Out:
# (2, 10000)

# %%
b = 0
z = X.dot(w_final) + b
A = 1/ (1+np.exp(-z))



epsilon = 1e-15
L =  1 / len(y) * np.sum(-y * np.log(A + epsilon) - (1 - y) * np.log(1 - A + epsilon), axis=0).reshape(w11.shape)
L.shape
# Out:
# (100, 100)

# %%
plt.contourf(w11, w22, L, cmap='magma')
plt.colorbar()
